# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
aryashah2k_breast_ultrasound_images_dataset_path = kagglehub.dataset_download('aryashah2k/breast-ultrasound-images-dataset')

print('Data source import complete.')
# Out:
# Data source import complete.

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#e5a3a3 ;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importing libraries </p>

# %%
# data preperation and processing
import os
import cv2
import random
import numpy as np

# data visulization
from PIL import Image
import matplotlib.pyplot as plt
import plotly.graph_objects as go


# for model building
import tensorflow as tf
from tensorflow.keras import layers, Model, Input
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#e5a3a3 ;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">EDA </p>

# %%
import kagglehub
import os

# Download dataset
dataset_path = kagglehub.dataset_download('aryashah2k/breast-ultrasound-images-dataset')

print("Actual dataset path:", dataset_path)

# Now explore its contents
for root, dirs, files in os.walk(dataset_path):
    print(root)
    for d in dirs:
        print(" -", d)
    for f in files[:5]:
        print(" -", f)
    break  # print only top-level to avoid clutter
# Out:
# Actual dataset path: /kaggle/input/breast-ultrasound-images-dataset
# /kaggle/input/breast-ultrasound-images-dataset
#  - Dataset_BUSI_with_GT

# %%
data_path = os.path.join(dataset_path, "Dataset_BUSI_with_GT")

# %%
image_counter = 0
mask_counter = 0

for folder_name in os.listdir(data_path):
    folder_content = os.path.join(data_path, folder_name)
    for image_name in os.listdir(folder_content):
        if '_mask' in image_name:
            mask_counter += 1
        else:
            image_counter += 1

    print(f"Images in {folder_name}: {image_counter}")
    print(f"Masks in {folder_name}: {mask_counter}")
    image_counter = 0
    mask_counter = 0
# Out:
# Images in benign: 437
# Masks in benign: 454
# Images in normal: 133
# Masks in normal: 133
# Images in malignant: 210
# Masks in malignant: 211

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# <strong> Notes  </strong>
#
#  Some image has more than one mask in **benign** and **malignant**

# %%
def vis_images(class_name, data_path=data_path, rows=2, cols=3, alpha=0.5):
    # to get all images path
    image_paths = sorted([
        os.path.join(data_path, class_name, img_name)
        for img_name in os.listdir(os.path.join(data_path, class_name))
        if "_mask" not in img_name
    ])
    # to get all masks path
    mask_paths = {
        os.path.basename(mask_name).replace("_mask", ""): os.path.join(data_path, class_name, mask_name)
        for mask_name in os.listdir(os.path.join(data_path, class_name)) if "_mask" in mask_name
    }

    # to get all images that has masks
    image_paths = [img for img in image_paths if os.path.basename(img) in mask_paths]

    # to ensure that we have enough images
    num_images = min(rows, len(image_paths))
    if num_images == 0:
        print(f"No valid images found for class: {class_name}")
        return

    # get random images to display
    random_images = random.sample(image_paths, num_images)

    fig, axes = plt.subplots(rows, cols, figsize=(12, 8))
    axes = axes.reshape(rows, cols)

    for idx, img_path in enumerate(random_images):
        mask_path = mask_paths[os.path.basename(img_path)]

        # read image and mask
        image = np.array(Image.open(img_path).convert("RGB"))
        mask = np.array(Image.open(mask_path).convert("L"))

        # convert mask to jet
        mask_colored = cv2.applyColorMap(mask, cv2.COLORMAP_JET)
        mask_colored = cv2.cvtColor(mask_colored, cv2.COLOR_BGR2RGB)

        # add the image to the colored mask
        overlay = cv2.addWeighted(image, 1, mask_colored, alpha, 0)

        # original image
        axes[idx, 0].imshow(image)
        axes[idx, 0].set_title("Original Image")
        axes[idx, 0].axis("off")

        # mask
        axes[idx, 1].imshow(mask, cmap="gray")
        axes[idx, 1].set_title("Mask")
        axes[idx, 1].axis("off")

        # union (original image with the mask>>>>)
        axes[idx, 2].imshow(overlay)
        axes[idx, 2].set_title("Union Image")
        axes[idx, 2].axis("off")

    plt.tight_layout()
    plt.show()

# %%
#from benign class
vis_images (class_name="benign")

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# <strong> Notes </strong>
#
# For the class **benign**  the  image masks are located correctly

# %% [markdown]
# -----

# %%
#from malignant class
vis_images (class_name="malignant")

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# <strong> Notes </strong>
#
# For the class **malignant**  the image masks are located correctly

# %% [markdown]
# -------

# %%
#from normal class
vis_images (class_name="normal")

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# <strong> Notes </strong>
#
# For the class **normal** there are no image masks

# %% [markdown]
# ---------

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#e5a3a3 ;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Data preprocessing </p>

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# Since the class **normal** does not contain masks, we will process only the data contained in both  **(benign and malignant)** and not-use **normal** calss
#
# As we noted previously, there are some images that have more than one mask. Therefore, the best solution is to combine all the masks for a single image into an image that includes all the masks (an image that includes all the masks for multi masked image).

# %%
# this example to show what i mean
# note in the image processing this process will be automated this example to clear the idea
image_path = "/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100).png" #this image from our dataset
mask_paths = [
    "/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100)_mask.png",# the image has two masks as shown
    "/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100)_mask_1.png"
]

image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image, (256, 256))

mask_combined = np.zeros((256, 256), dtype=np.uint8) # balck image to add the masks on it
for mask_path in mask_paths:
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (256, 256))
    mask_combined = np.maximum(mask_combined, mask)# to combine the masks if an image has more than one mask

# easy code to display the image >>^^
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap="gray")
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(mask_combined, cmap="gray")
plt.title("Merged Mask")
plt.axis("off")

union = cv2.addWeighted(image, 0.2, mask_combined, 0.5, 0)
plt.subplot(1, 3, 3)
plt.imshow(union, cmap="jet")
plt.title("Union (Image + Mask)")
plt.axis("off")

plt.show()

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# 🔘  As is clear, the masks for the image mentioned in the example have been combined into one image, and this is what is required

# %%
def load_data(dataset_path):
    images = []  # List to store preprocessed images
    masks = []   # List to store corresponding lesion masks
    labels = []  # List to store class labels (0: benign, 1: malignant, 2: normal)

    label_map = {"benign": 0, "malignant": 1, "normal": 2}  # Added "normal" category

    for category in ["benign", "malignant", "normal"]:
        category_path = os.path.join(dataset_path, category)

        # Get all image filenames that are not masks
        image_files = [f for f in os.listdir(category_path) if "_mask" not in f]

        for img_file in image_files:
            img_path = os.path.join(category_path, img_file)
            base_name = img_file.split(".")[0]

            # ----------- Process the Image -----------
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (256, 256))
            img = cv2.GaussianBlur(img, (3, 3), 0)
            img = img / 255.0
            images.append(img)

            # ----------- Process the Mask -----------
            if category != "normal":
                mask_paths = sorted([
                    os.path.join(category_path, f)
                    for f in os.listdir(category_path)
                    if f.startswith(base_name + "_mask")
                ])

                mask_combined = np.zeros((256, 256), dtype=np.uint8)
                for mask_path in mask_paths:
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    mask = cv2.resize(mask, (256, 256))
                    mask_combined = np.maximum(mask_combined, mask)
                masks.append(mask_combined / 255.0)
            else:
                # Normal images have no mask — use a blank one
                masks.append(np.zeros((256, 256), dtype=np.float32))

            labels.append(label_map[category])

    # Convert to numpy arrays
    images = np.array(images).reshape(-1, 256, 256, 1)
    masks = np.array(masks).reshape(-1, 256, 256, 1)
    labels = np.array(labels)

    return images, masks, labels

# %%
# Load dataset
dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'

# Load images (X), masks (Y), and labels (ignored here using '_')
X, Y, _ = load_data(dataset_path)  # X: ultrasound images, Y: lesion masks

# Split dataset into training and testing sets (80% train, 20% test)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Shapes:")
print("X_train:", X_train.shape)
print("Y_train:", Y_train.shape)
print("X_test :", X_test.shape)
print("Y_test :", Y_test.shape)
# Out:
# Shapes:
# X_train: (624, 256, 256, 1)
# Y_train: (624, 256, 256, 1)
# X_test : (156, 256, 256, 1)
# Y_test : (156, 256, 256, 1)

# %%
X_train.shape , Y_train.shape # Batch_size , image dims(h,w) , n_channels
# Out:
# ((624, 256, 256, 1), (624, 256, 256, 1))

# %%
X_test.shape , Y_test.shape
# Out:
# ((156, 256, 256, 1), (156, 256, 256, 1))

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#e5a3a3 ;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Model Building </p>

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
#
# 🔘 **U-Net** is a convolutional neural network (CNN) architecture specifically designed for **semantic segmentation tasks**. Initially developed for biomedical image segmentation, U-Net has proven to be highly effective in tasks requiring pixel-level classification, where the goal is to assign a label to each pixel in an image. The architecture consists of two main parts: an encoder and a decoder, which are connected through skip connections.
#
# 🔘 **Encoder:** The encoder (also known as the contracting path) progressively **reduces the spatial dimensions of the input image using convolutional layers** followed by pooling layers. This captures high-level features and abstracts the image.
#
# 🔘 **Decoder:** The decoder (or expansive path) upsamples the feature maps to **reconstruct the spatial dimensions**. It combines the upsampled features with the corresponding feature maps from the encoder via skip connections. This helps the network retain spatial information, which is crucial for precise segmentation.
#
# 🔘 **Skip Connections:** These connections between the encoder and decoder allow the network to retain fine-grained details and context, which is essential for accurate segmentation, particularly at the boundaries of objects.

# %% [markdown]
# <div style = 'border : 3px solid #e5a3a3; background-color:#f7e9e9;padding:10px; border-radius: 25px;'>
#
# **Why Use U-Net for Breast Cancer Segmentation?**
#
#   - High Accuracy in Semantic Segmentation: U-Net is widely regarded for its performance in tasks involving the precise segmentation of structures, which is critical in medical image analysis, such as detecting tumors in breast ultrasound images.
#
#   - Efficient with Limited Data: U-Net's design makes it well-suited for scenarios where the available data is limited. This is important in medical imaging, where annotated data is often scarce.
#
#   - Preserves Spatial Information: The skip connections in U-Net help preserve spatial information throughout the encoding-decoding process, making it more effective in segmenting complex structures with varying shapes and sizes, such as tumors, while maintaining high resolution at the pixel level.
#
#   - Established Success in Medical Imaging: U-Net has been extensively tested and utilized in various medical image segmentation tasks, including breast cancer detection, proving its robustness and reliability in real-world medical applications.

# %% [markdown]
# - Try Different Variation

# %%
checkpoint = ModelCheckpoint('best_model.keras',
                             monitor='val_loss',
                             save_best_only=True,
                             verbose=1)


early_stopping = EarlyStopping(monitor='val_accuracy',
                               patience=15,
                               restore_best_weights=True,
                               verbose=1)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Save the model that has the best validation SEGMENTATION loss
checkpoint = ModelCheckpoint('best_multi_task_model.keras',
                             monitor='val_seg_output_loss',  # Monitor segmentation head loss
                             save_best_only=True,
                             verbose=1)

# Stop training if classification accuracy doesn't improve
early_stopping = EarlyStopping(monitor='val_cls_output_accuracy',  # Monitor classification accuracy
                               patience=15,
                               restore_best_weights=True,
                               verbose=1)

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def load_data(dataset_path):
    images = []  # List to store preprocessed images
    masks = []   # List to store corresponding lesion masks
    labels = []  # List to store class labels (0: benign, 1: malignant, 2: normal)

    label_map = {"benign": 0, "malignant": 1, "normal": 2}  # Added "normal" category

    for category in ["benign", "malignant", "normal"]:
        category_path = os.path.join(dataset_path, category)

        # Get all image filenames that are not masks
        image_files = [f for f in os.listdir(category_path) if "_mask" not in f]

        for img_file in image_files:
            img_path = os.path.join(category_path, img_file)
            base_name = img_file.split(".")[0]

            # ----------- Process the Image -----------
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (256, 256))
            img = cv2.GaussianBlur(img, (3, 3), 0)
            img = img / 255.0
            images.append(img)

            # ----------- Process the Mask -----------
            if category != "normal":
                mask_paths = sorted([
                    os.path.join(category_path, f)
                    for f in os.listdir(category_path)
                    if f.startswith(base_name + "_mask")
                ])

                mask_combined = np.zeros((256, 256), dtype=np.uint8)
                for mask_path in mask_paths:
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    mask = cv2.resize(mask, (256, 256))
                    mask_combined = np.maximum(mask_combined, mask)
                masks.append(mask_combined / 255.0)
            else:
                # Normal images have no mask — use a blank one
                masks.append(np.zeros((256, 256), dtype=np.float32))

            labels.append(label_map[category])

    # Convert to numpy arrays
    images = np.array(images).reshape(-1, 256, 256, 1)
    masks = np.array(masks).reshape(-1, 256, 256, 1)
    labels = np.array(labels)

    return images, masks, labels



# Load dataset
dataset_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT'
X, Y, class_labels = load_data(dataset_path)

# One-hot encode class labels (0 or 1 -> [1, 0] or [0, 1])
Y_class = to_categorical(class_labels, num_classes=3)

# Train-test split
X_train, X_test, Y_train, Y_test, Y_class_train, Y_class_test = train_test_split(
    X, Y, Y_class, test_size=0.2, random_state=42
)

print("Shapes:")
print("X_train      :", X_train.shape)
print("Y_train      :", Y_train.shape)
print("Y_class_train:", Y_class_train.shape)
print("X_test       :", X_test.shape)
print("Y_test       :", Y_test.shape)
print("Y_class_test :", Y_class_test.shape)
# Out:
# Shapes:
# X_train      : (624, 256, 256, 1)
# Y_train      : (624, 256, 256, 1)
# Y_class_train: (624, 3)
# X_test       : (156, 256, 256, 1)
# Y_test       : (156, 256, 256, 1)
# Y_class_test : (156, 3)

# %%
from tensorflow.keras import layers, models

def build_multi_output_unet(input_shape=(256, 256, 1)):
    inputs = layers.Input(shape=input_shape)

    # --- U-Net Encoding Path ---
    c1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p1)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    # --- Bottleneck ---
    bn = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p2)

    # --- U-Net Decoding Path ---
    u1 = layers.UpSampling2D((2, 2))(bn)
    m1 = layers.Concatenate()([u1, c2])
    c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(m1)

    u2 = layers.UpSampling2D((2, 2))(c3)
    m2 = layers.Concatenate()([u2, c1])
    c4 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(m2)

    # --- Segmentation Output ---
    seg_output = layers.Conv2D(1, (1, 1), activation='sigmoid', name='seg_output')(c4)

    # --- Classification Output ---
    flat = layers.GlobalAveragePooling2D()(bn)  # Use bottleneck features
    dense1 = layers.Dense(64, activation='relu')(flat)
    cls_output = layers.Dense(3, activation='softmax', name='cls_output')(dense1)  # Changed to 3 classes

    model = models.Model(inputs=inputs, outputs=[seg_output, cls_output])
    return model

# %%
model = build_multi_output_unet()

model.compile(
    optimizer='adam',
    loss={
        'seg_output': 'binary_crossentropy',
        'cls_output': 'categorical_crossentropy'
    },
    metrics={
        'seg_output': ['accuracy'],
        'cls_output': ['accuracy']
    }
)

# %%
history = model.fit(
    X_train,
    {'seg_output': Y_train, 'cls_output': Y_class_train},
    validation_data=(X_test, {'seg_output': Y_test, 'cls_output': Y_class_test}),
    epochs=100,
    batch_size=8,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.5533 - cls_output_loss: 1.0062 - loss: 1.3959 - seg_output_accuracy: 0.9222 - seg_output_loss: 0.3896
# Epoch 1: val_loss improved from inf to 1.26312, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - cls_output_accuracy: 0.5534 - cls_output_loss: 1.0062 - loss: 1.3939 - seg_output_accuracy: 0.9222 - seg_output_loss: 0.3878 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9904 - val_loss: 1.2631 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2635
# Epoch 2/100
#  3/78 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - cls_output_accuracy: 0.7083 - cls_output_loss: 0.8508 - loss: 1.0718 - seg_output_accuracy: 0.9409 - seg_output_loss: 0.2210
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: cls_output_accuracy,cls_output_loss,loss,seg_output_accuracy,seg_output_loss,val_cls_output_accuracy,val_cls_output_loss,val_loss,val_seg_output_accuracy,val_seg_output_loss
#   current = self.get_monitor_value(logs)
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5764 - cls_output_loss: 0.9616 - loss: 1.2171 - seg_output_accuracy: 0.9269 - seg_output_loss: 0.2555
# Epoch 2: val_loss improved from 1.26312 to 1.24945, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.5761 - cls_output_loss: 0.9620 - loss: 1.2179 - seg_output_accuracy: 0.9267 - seg_output_loss: 0.2559 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9859 - val_loss: 1.2495 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2529
# Epoch 3/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5453 - cls_output_loss: 0.9904 - loss: 1.2686 - seg_output_accuracy: 0.9148 - seg_output_loss: 0.2782
# Epoch 3: val_loss did not improve from 1.24945
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - cls_output_accuracy: 0.5458 - cls_output_loss: 0.9900 - loss: 1.2679 - seg_output_accuracy: 0.9149 - seg_output_loss: 0.2779 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9869 - val_loss: 1.2534 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2559
# Epoch 4/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.5503 - cls_output_loss: 0.9773 - loss: 1.2516 - seg_output_accuracy: 0.9171 - seg_output_loss: 0.2743
# Epoch 4: val_loss improved from 1.24945 to 1.24149, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.5507 - cls_output_loss: 0.9771 - loss: 1.2513 - seg_output_accuracy: 0.9171 - seg_output_loss: 0.2742 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9843 - val_loss: 1.2415 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2463
# Epoch 5/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5944 - cls_output_loss: 0.9493 - loss: 1.2038 - seg_output_accuracy: 0.9226 - seg_output_loss: 0.2545
# Epoch 5: val_loss did not improve from 1.24149
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.5937 - cls_output_loss: 0.9498 - loss: 1.2045 - seg_output_accuracy: 0.9225 - seg_output_loss: 0.2547 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9854 - val_loss: 1.2520 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2549
# Epoch 6/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.5091 - cls_output_loss: 1.0138 - loss: 1.2847 - seg_output_accuracy: 0.9146 - seg_output_loss: 0.2709
# Epoch 6: val_loss did not improve from 1.24149
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - cls_output_accuracy: 0.5106 - cls_output_loss: 1.0126 - loss: 1.2832 - seg_output_accuracy: 0.9147 - seg_output_loss: 0.2706 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 1.0091 - val_loss: 1.2849 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2588
# Epoch 7/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.5673 - cls_output_loss: 0.9635 - loss: 1.2156 - seg_output_accuracy: 0.9245 - seg_output_loss: 0.2521
# Epoch 7: val_loss improved from 1.24149 to 1.23996, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.5673 - cls_output_loss: 0.9636 - loss: 1.2158 - seg_output_accuracy: 0.9244 - seg_output_loss: 0.2522 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9854 - val_loss: 1.2400 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2455
# Epoch 8/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.5553 - cls_output_loss: 0.9848 - loss: 1.2459 - seg_output_accuracy: 0.9164 - seg_output_loss: 0.2612
# Epoch 8: val_loss did not improve from 1.23996
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - cls_output_accuracy: 0.5556 - cls_output_loss: 0.9844 - loss: 1.2453 - seg_output_accuracy: 0.9164 - seg_output_loss: 0.2610 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9861 - val_loss: 1.2446 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2453
# Epoch 9/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.5427 - cls_output_loss: 0.9985 - loss: 1.2331 - seg_output_accuracy: 0.9296 - seg_output_loss: 0.2346
# Epoch 9: val_loss improved from 1.23996 to 1.23780, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.5433 - cls_output_loss: 0.9977 - loss: 1.2329 - seg_output_accuracy: 0.9293 - seg_output_loss: 0.2352 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9842 - val_loss: 1.2378 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2409
# Epoch 10/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5487 - cls_output_loss: 0.9834 - loss: 1.2257 - seg_output_accuracy: 0.9249 - seg_output_loss: 0.2424
# Epoch 10: val_loss did not improve from 1.23780
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.5491 - cls_output_loss: 0.9829 - loss: 1.2255 - seg_output_accuracy: 0.9248 - seg_output_loss: 0.2426 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9815 - val_loss: 1.2395 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2450
# Epoch 11/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.5730 - cls_output_loss: 0.9519 - loss: 1.1966 - seg_output_accuracy: 0.9211 - seg_output_loss: 0.2447
# Epoch 11: val_loss improved from 1.23780 to 1.23069, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.5728 - cls_output_loss: 0.9521 - loss: 1.1970 - seg_output_accuracy: 0.9210 - seg_output_loss: 0.2449 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9789 - val_loss: 1.2307 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2417
# Epoch 12/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5694 - cls_output_loss: 0.9628 - loss: 1.2076 - seg_output_accuracy: 0.9230 - seg_output_loss: 0.2449
# Epoch 12: val_loss did not improve from 1.23069
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.5693 - cls_output_loss: 0.9627 - loss: 1.2077 - seg_output_accuracy: 0.9230 - seg_output_loss: 0.2450 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9934 - val_loss: 1.2387 - val_seg_output_accuracy: 0.9245 - val_seg_output_loss: 0.2378
# Epoch 13/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.5683 - cls_output_loss: 0.9754 - loss: 1.2167 - seg_output_accuracy: 0.9235 - seg_output_loss: 0.2413
# Epoch 13: val_loss improved from 1.23069 to 1.22042, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.5683 - cls_output_loss: 0.9753 - loss: 1.2166 - seg_output_accuracy: 0.9235 - seg_output_loss: 0.2414 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9736 - val_loss: 1.2204 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2342
# Epoch 14/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.5476 - cls_output_loss: 0.9859 - loss: 1.2229 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2370
# Epoch 14: val_loss did not improve from 1.22042
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.5480 - cls_output_loss: 0.9852 - loss: 1.2223 - seg_output_accuracy: 0.9236 - seg_output_loss: 0.2371 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9934 - val_loss: 1.2375 - val_seg_output_accuracy: 0.9239 - val_seg_output_loss: 0.2275
# Epoch 15/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.5715 - cls_output_loss: 0.9595 - loss: 1.1931 - seg_output_accuracy: 0.9238 - seg_output_loss: 0.2336
# Epoch 15: val_loss improved from 1.22042 to 1.20408, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - cls_output_accuracy: 0.5714 - cls_output_loss: 0.9595 - loss: 1.1933 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2338 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9635 - val_loss: 1.2041 - val_seg_output_accuracy: 0.9248 - val_seg_output_loss: 0.2294
# Epoch 16/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5699 - cls_output_loss: 0.9582 - loss: 1.1918 - seg_output_accuracy: 0.9234 - seg_output_loss: 0.2336
# Epoch 16: val_loss did not improve from 1.20408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.5698 - cls_output_loss: 0.9581 - loss: 1.1918 - seg_output_accuracy: 0.9234 - seg_output_loss: 0.2337 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 1.0993 - val_loss: 1.3503 - val_seg_output_accuracy: 0.9250 - val_seg_output_loss: 0.2274
# Epoch 17/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5703 - cls_output_loss: 0.9701 - loss: 1.2141 - seg_output_accuracy: 0.9202 - seg_output_loss: 0.2440
# Epoch 17: val_loss did not improve from 1.20408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - cls_output_accuracy: 0.5702 - cls_output_loss: 0.9701 - loss: 1.2142 - seg_output_accuracy: 0.9202 - seg_output_loss: 0.2441 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9742 - val_loss: 1.2179 - val_seg_output_accuracy: 0.9247 - val_seg_output_loss: 0.2346
# Epoch 18/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - cls_output_accuracy: 0.5571 - cls_output_loss: 0.9594 - loss: 1.1976 - seg_output_accuracy: 0.9227 - seg_output_loss: 0.2382
# Epoch 18: val_loss did not improve from 1.20408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - cls_output_accuracy: 0.5572 - cls_output_loss: 0.9593 - loss: 1.1975 - seg_output_accuracy: 0.9227 - seg_output_loss: 0.2383 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9900 - val_loss: 1.2317 - val_seg_output_accuracy: 0.9254 - val_seg_output_loss: 0.2248
# Epoch 19/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5961 - cls_output_loss: 0.9005 - loss: 1.1479 - seg_output_accuracy: 0.9188 - seg_output_loss: 0.2474
# Epoch 19: val_loss did not improve from 1.20408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.5954 - cls_output_loss: 0.9015 - loss: 1.1487 - seg_output_accuracy: 0.9189 - seg_output_loss: 0.2472 - val_cls_output_accuracy: 0.5385 - val_cls_output_loss: 0.9630 - val_loss: 1.2167 - val_seg_output_accuracy: 0.9255 - val_seg_output_loss: 0.2390
# Epoch 20/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.5701 - cls_output_loss: 0.9205 - loss: 1.1646 - seg_output_accuracy: 0.9202 - seg_output_loss: 0.2440
# Epoch 20: val_loss improved from 1.20408 to 1.17958, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.5701 - cls_output_loss: 0.9207 - loss: 1.1647 - seg_output_accuracy: 0.9202 - seg_output_loss: 0.2440 - val_cls_output_accuracy: 0.5641 - val_cls_output_loss: 0.9412 - val_loss: 1.1796 - val_seg_output_accuracy: 0.9244 - val_seg_output_loss: 0.2270
# Epoch 21/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.5853 - cls_output_loss: 0.9222 - loss: 1.1627 - seg_output_accuracy: 0.9203 - seg_output_loss: 0.2405
# Epoch 21: val_loss did not improve from 1.17958
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.5856 - cls_output_loss: 0.9219 - loss: 1.1624 - seg_output_accuracy: 0.9203 - seg_output_loss: 0.2405 - val_cls_output_accuracy: 0.5641 - val_cls_output_loss: 0.9546 - val_loss: 1.1968 - val_seg_output_accuracy: 0.9256 - val_seg_output_loss: 0.2262
# Epoch 22/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6271 - cls_output_loss: 0.8701 - loss: 1.1155 - seg_output_accuracy: 0.9198 - seg_output_loss: 0.2454
# Epoch 22: val_loss improved from 1.17958 to 1.17823, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.6262 - cls_output_loss: 0.8713 - loss: 1.1167 - seg_output_accuracy: 0.9198 - seg_output_loss: 0.2454 - val_cls_output_accuracy: 0.5769 - val_cls_output_loss: 0.9349 - val_loss: 1.1782 - val_seg_output_accuracy: 0.9243 - val_seg_output_loss: 0.2334
# Epoch 23/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6252 - cls_output_loss: 0.8839 - loss: 1.1205 - seg_output_accuracy: 0.9217 - seg_output_loss: 0.2366
# Epoch 23: val_loss improved from 1.17823 to 1.15748, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6247 - cls_output_loss: 0.8844 - loss: 1.1210 - seg_output_accuracy: 0.9217 - seg_output_loss: 0.2366 - val_cls_output_accuracy: 0.6218 - val_cls_output_loss: 0.9176 - val_loss: 1.1575 - val_seg_output_accuracy: 0.9248 - val_seg_output_loss: 0.2286
# Epoch 24/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6043 - cls_output_loss: 0.8985 - loss: 1.1212 - seg_output_accuracy: 0.9270 - seg_output_loss: 0.2228
# Epoch 24: val_loss did not improve from 1.15748
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.6046 - cls_output_loss: 0.8984 - loss: 1.1216 - seg_output_accuracy: 0.9268 - seg_output_loss: 0.2231 - val_cls_output_accuracy: 0.6282 - val_cls_output_loss: 0.9258 - val_loss: 1.1709 - val_seg_output_accuracy: 0.9250 - val_seg_output_loss: 0.2330
# Epoch 25/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6679 - cls_output_loss: 0.8291 - loss: 1.0749 - seg_output_accuracy: 0.9160 - seg_output_loss: 0.2458
# Epoch 25: val_loss did not improve from 1.15748
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.6671 - cls_output_loss: 0.8296 - loss: 1.0752 - seg_output_accuracy: 0.9161 - seg_output_loss: 0.2456 - val_cls_output_accuracy: 0.5897 - val_cls_output_loss: 0.9361 - val_loss: 1.1676 - val_seg_output_accuracy: 0.9256 - val_seg_output_loss: 0.2181
# Epoch 26/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6790 - cls_output_loss: 0.8443 - loss: 1.0797 - seg_output_accuracy: 0.9220 - seg_output_loss: 0.2354
# Epoch 26: val_loss improved from 1.15748 to 1.13322, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.6784 - cls_output_loss: 0.8449 - loss: 1.0803 - seg_output_accuracy: 0.9220 - seg_output_loss: 0.2354 - val_cls_output_accuracy: 0.6090 - val_cls_output_loss: 0.8984 - val_loss: 1.1332 - val_seg_output_accuracy: 0.9249 - val_seg_output_loss: 0.2213
# Epoch 27/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6522 - cls_output_loss: 0.8302 - loss: 1.0741 - seg_output_accuracy: 0.9179 - seg_output_loss: 0.2439
# Epoch 27: val_loss did not improve from 1.13322
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.6518 - cls_output_loss: 0.8306 - loss: 1.0744 - seg_output_accuracy: 0.9180 - seg_output_loss: 0.2438 - val_cls_output_accuracy: 0.6346 - val_cls_output_loss: 0.8978 - val_loss: 1.1338 - val_seg_output_accuracy: 0.9253 - val_seg_output_loss: 0.2239
# Epoch 28/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.6572 - cls_output_loss: 0.8138 - loss: 1.0571 - seg_output_accuracy: 0.9190 - seg_output_loss: 0.2433
# Epoch 28: val_loss improved from 1.13322 to 1.13033, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.6569 - cls_output_loss: 0.8140 - loss: 1.0573 - seg_output_accuracy: 0.9191 - seg_output_loss: 0.2432 - val_cls_output_accuracy: 0.6218 - val_cls_output_loss: 0.8919 - val_loss: 1.1303 - val_seg_output_accuracy: 0.9255 - val_seg_output_loss: 0.2252
# Epoch 29/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6414 - cls_output_loss: 0.8005 - loss: 1.0314 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2310
# Epoch 29: val_loss improved from 1.13033 to 1.11867, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6418 - cls_output_loss: 0.8006 - loss: 1.0317 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2311 - val_cls_output_accuracy: 0.6218 - val_cls_output_loss: 0.8818 - val_loss: 1.1187 - val_seg_output_accuracy: 0.9249 - val_seg_output_loss: 0.2253
# Epoch 30/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6373 - cls_output_loss: 0.8188 - loss: 1.0423 - seg_output_accuracy: 0.9268 - seg_output_loss: 0.2234
# Epoch 30: val_loss improved from 1.11867 to 1.10208, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6377 - cls_output_loss: 0.8182 - loss: 1.0420 - seg_output_accuracy: 0.9267 - seg_output_loss: 0.2238 - val_cls_output_accuracy: 0.6538 - val_cls_output_loss: 0.8744 - val_loss: 1.1021 - val_seg_output_accuracy: 0.9256 - val_seg_output_loss: 0.2195
# Epoch 31/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6665 - cls_output_loss: 0.7595 - loss: 0.9912 - seg_output_accuracy: 0.9220 - seg_output_loss: 0.2318
# Epoch 31: val_loss did not improve from 1.10208
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.6661 - cls_output_loss: 0.7598 - loss: 0.9917 - seg_output_accuracy: 0.9220 - seg_output_loss: 0.2319 - val_cls_output_accuracy: 0.5897 - val_cls_output_loss: 0.9685 - val_loss: 1.2141 - val_seg_output_accuracy: 0.9242 - val_seg_output_loss: 0.2274
# Epoch 32/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6325 - cls_output_loss: 0.8265 - loss: 1.0591 - seg_output_accuracy: 0.9214 - seg_output_loss: 0.2326
# Epoch 32: val_loss did not improve from 1.10208
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.6328 - cls_output_loss: 0.8259 - loss: 1.0585 - seg_output_accuracy: 0.9214 - seg_output_loss: 0.2326 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.9010 - val_loss: 1.1356 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2234
# Epoch 33/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6449 - cls_output_loss: 0.7817 - loss: 1.0221 - seg_output_accuracy: 0.9201 - seg_output_loss: 0.2403
# Epoch 33: val_loss did not improve from 1.10208
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6451 - cls_output_loss: 0.7817 - loss: 1.0219 - seg_output_accuracy: 0.9201 - seg_output_loss: 0.2402 - val_cls_output_accuracy: 0.6218 - val_cls_output_loss: 0.8834 - val_loss: 1.1128 - val_seg_output_accuracy: 0.9261 - val_seg_output_loss: 0.2175
# Epoch 34/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6535 - cls_output_loss: 0.7397 - loss: 0.9797 - seg_output_accuracy: 0.9193 - seg_output_loss: 0.2400
# Epoch 34: val_loss improved from 1.10208 to 1.09386, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.6535 - cls_output_loss: 0.7402 - loss: 0.9801 - seg_output_accuracy: 0.9193 - seg_output_loss: 0.2399 - val_cls_output_accuracy: 0.6474 - val_cls_output_loss: 0.8634 - val_loss: 1.0939 - val_seg_output_accuracy: 0.9261 - val_seg_output_loss: 0.2206
# Epoch 35/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.6583 - cls_output_loss: 0.7583 - loss: 0.9854 - seg_output_accuracy: 0.9256 - seg_output_loss: 0.2271
# Epoch 35: val_loss did not improve from 1.09386
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.6587 - cls_output_loss: 0.7584 - loss: 0.9857 - seg_output_accuracy: 0.9255 - seg_output_loss: 0.2273 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.8723 - val_loss: 1.1111 - val_seg_output_accuracy: 0.9249 - val_seg_output_loss: 0.2266
# Epoch 36/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6434 - cls_output_loss: 0.8184 - loss: 1.0561 - seg_output_accuracy: 0.9209 - seg_output_loss: 0.2377
# Epoch 36: val_loss did not improve from 1.09386
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.6440 - cls_output_loss: 0.8175 - loss: 1.0551 - seg_output_accuracy: 0.9210 - seg_output_loss: 0.2376 - val_cls_output_accuracy: 0.6474 - val_cls_output_loss: 0.8710 - val_loss: 1.1004 - val_seg_output_accuracy: 0.9258 - val_seg_output_loss: 0.2195
# Epoch 37/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6689 - cls_output_loss: 0.7547 - loss: 0.9974 - seg_output_accuracy: 0.9193 - seg_output_loss: 0.2427
# Epoch 37: val_loss did not improve from 1.09386
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.6690 - cls_output_loss: 0.7549 - loss: 0.9974 - seg_output_accuracy: 0.9194 - seg_output_loss: 0.2425 - val_cls_output_accuracy: 0.5256 - val_cls_output_loss: 0.9220 - val_loss: 1.1459 - val_seg_output_accuracy: 0.9261 - val_seg_output_loss: 0.2206
# Epoch 38/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.6960 - cls_output_loss: 0.7603 - loss: 0.9871 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2268
# Epoch 38: val_loss improved from 1.09386 to 1.07328, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.6957 - cls_output_loss: 0.7603 - loss: 0.9872 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2269 - val_cls_output_accuracy: 0.6731 - val_cls_output_loss: 0.8471 - val_loss: 1.0733 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2190
# Epoch 39/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6979 - cls_output_loss: 0.7440 - loss: 0.9773 - seg_output_accuracy: 0.9218 - seg_output_loss: 0.2333
# Epoch 39: val_loss did not improve from 1.07328
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.6974 - cls_output_loss: 0.7444 - loss: 0.9778 - seg_output_accuracy: 0.9219 - seg_output_loss: 0.2334 - val_cls_output_accuracy: 0.6090 - val_cls_output_loss: 0.9169 - val_loss: 1.1435 - val_seg_output_accuracy: 0.9260 - val_seg_output_loss: 0.2168
# Epoch 40/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6881 - cls_output_loss: 0.7532 - loss: 0.9766 - seg_output_accuracy: 0.9250 - seg_output_loss: 0.2234
# Epoch 40: val_loss did not improve from 1.07328
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.6878 - cls_output_loss: 0.7530 - loss: 0.9765 - seg_output_accuracy: 0.9250 - seg_output_loss: 0.2236 - val_cls_output_accuracy: 0.5064 - val_cls_output_loss: 1.0695 - val_loss: 1.3010 - val_seg_output_accuracy: 0.9260 - val_seg_output_loss: 0.2217
# Epoch 41/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6819 - cls_output_loss: 0.7764 - loss: 1.0207 - seg_output_accuracy: 0.9186 - seg_output_loss: 0.2443
# Epoch 41: val_loss did not improve from 1.07328
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6818 - cls_output_loss: 0.7763 - loss: 1.0204 - seg_output_accuracy: 0.9187 - seg_output_loss: 0.2440 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.8496 - val_loss: 1.0793 - val_seg_output_accuracy: 0.9264 - val_seg_output_loss: 0.2186
# Epoch 42/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6853 - cls_output_loss: 0.7477 - loss: 0.9807 - seg_output_accuracy: 0.9212 - seg_output_loss: 0.2330
# Epoch 42: val_loss did not improve from 1.07328
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.6859 - cls_output_loss: 0.7473 - loss: 0.9803 - seg_output_accuracy: 0.9212 - seg_output_loss: 0.2330 - val_cls_output_accuracy: 0.6090 - val_cls_output_loss: 0.9448 - val_loss: 1.1845 - val_seg_output_accuracy: 0.9264 - val_seg_output_loss: 0.2222
# Epoch 43/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.6834 - cls_output_loss: 0.7570 - loss: 0.9925 - seg_output_accuracy: 0.9204 - seg_output_loss: 0.2355
# Epoch 43: val_loss did not improve from 1.07328
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - cls_output_accuracy: 0.6836 - cls_output_loss: 0.7566 - loss: 0.9920 - seg_output_accuracy: 0.9205 - seg_output_loss: 0.2354 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.8508 - val_loss: 1.0835 - val_seg_output_accuracy: 0.9263 - val_seg_output_loss: 0.2200
# Epoch 44/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7225 - cls_output_loss: 0.7049 - loss: 0.9336 - seg_output_accuracy: 0.9228 - seg_output_loss: 0.2287
# Epoch 44: val_loss improved from 1.07328 to 1.03722, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.7221 - cls_output_loss: 0.7054 - loss: 0.9342 - seg_output_accuracy: 0.9228 - seg_output_loss: 0.2288 - val_cls_output_accuracy: 0.6795 - val_cls_output_loss: 0.8144 - val_loss: 1.0372 - val_seg_output_accuracy: 0.9267 - val_seg_output_loss: 0.2164
# Epoch 45/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7040 - cls_output_loss: 0.6875 - loss: 0.9324 - seg_output_accuracy: 0.9163 - seg_output_loss: 0.2449
# Epoch 45: val_loss did not improve from 1.03722
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.7039 - cls_output_loss: 0.6885 - loss: 0.9331 - seg_output_accuracy: 0.9164 - seg_output_loss: 0.2446 - val_cls_output_accuracy: 0.5769 - val_cls_output_loss: 0.9343 - val_loss: 1.1618 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2189
# Epoch 46/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6796 - cls_output_loss: 0.7191 - loss: 0.9653 - seg_output_accuracy: 0.9171 - seg_output_loss: 0.2462
# Epoch 46: val_loss did not improve from 1.03722
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.6801 - cls_output_loss: 0.7192 - loss: 0.9651 - seg_output_accuracy: 0.9172 - seg_output_loss: 0.2459 - val_cls_output_accuracy: 0.6603 - val_cls_output_loss: 0.8270 - val_loss: 1.0522 - val_seg_output_accuracy: 0.9268 - val_seg_output_loss: 0.2202
# Epoch 47/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7149 - cls_output_loss: 0.7026 - loss: 0.9420 - seg_output_accuracy: 0.9183 - seg_output_loss: 0.2395
# Epoch 47: val_loss did not improve from 1.03722
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7145 - cls_output_loss: 0.7032 - loss: 0.9424 - seg_output_accuracy: 0.9184 - seg_output_loss: 0.2392 - val_cls_output_accuracy: 0.6731 - val_cls_output_loss: 0.8172 - val_loss: 1.0401 - val_seg_output_accuracy: 0.9266 - val_seg_output_loss: 0.2160
# Epoch 48/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6945 - cls_output_loss: 0.7275 - loss: 0.9553 - seg_output_accuracy: 0.9236 - seg_output_loss: 0.2277
# Epoch 48: val_loss did not improve from 1.03722
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.6945 - cls_output_loss: 0.7276 - loss: 0.9554 - seg_output_accuracy: 0.9236 - seg_output_loss: 0.2278 - val_cls_output_accuracy: 0.6474 - val_cls_output_loss: 0.8477 - val_loss: 1.0774 - val_seg_output_accuracy: 0.9266 - val_seg_output_loss: 0.2188
# Epoch 49/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.6780 - cls_output_loss: 0.7571 - loss: 0.9829 - seg_output_accuracy: 0.9253 - seg_output_loss: 0.2258
# Epoch 49: val_loss improved from 1.03722 to 1.03142, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.6784 - cls_output_loss: 0.7562 - loss: 0.9822 - seg_output_accuracy: 0.9252 - seg_output_loss: 0.2260 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.8022 - val_loss: 1.0314 - val_seg_output_accuracy: 0.9263 - val_seg_output_loss: 0.2206
# Epoch 50/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7131 - cls_output_loss: 0.7053 - loss: 0.9399 - seg_output_accuracy: 0.9199 - seg_output_loss: 0.2347
# Epoch 50: val_loss did not improve from 1.03142
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.7132 - cls_output_loss: 0.7052 - loss: 0.9397 - seg_output_accuracy: 0.9199 - seg_output_loss: 0.2345 - val_cls_output_accuracy: 0.6603 - val_cls_output_loss: 0.8145 - val_loss: 1.0378 - val_seg_output_accuracy: 0.9270 - val_seg_output_loss: 0.2141
# Epoch 51/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7619 - cls_output_loss: 0.6404 - loss: 0.8647 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2243
# Epoch 51: val_loss did not improve from 1.03142
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7613 - cls_output_loss: 0.6420 - loss: 0.8664 - seg_output_accuracy: 0.9237 - seg_output_loss: 0.2245 - val_cls_output_accuracy: 0.6603 - val_cls_output_loss: 0.8242 - val_loss: 1.0496 - val_seg_output_accuracy: 0.9268 - val_seg_output_loss: 0.2186
# Epoch 52/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6573 - cls_output_loss: 0.7609 - loss: 0.9947 - seg_output_accuracy: 0.9219 - seg_output_loss: 0.2338
# Epoch 52: val_loss improved from 1.03142 to 1.02660, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.6582 - cls_output_loss: 0.7597 - loss: 0.9934 - seg_output_accuracy: 0.9219 - seg_output_loss: 0.2337 - val_cls_output_accuracy: 0.6538 - val_cls_output_loss: 0.8034 - val_loss: 1.0266 - val_seg_output_accuracy: 0.9269 - val_seg_output_loss: 0.2185
# Epoch 53/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7155 - cls_output_loss: 0.6703 - loss: 0.8918 - seg_output_accuracy: 0.9271 - seg_output_loss: 0.2215
# Epoch 53: val_loss did not improve from 1.02660
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7153 - cls_output_loss: 0.6707 - loss: 0.8924 - seg_output_accuracy: 0.9270 - seg_output_loss: 0.2217 - val_cls_output_accuracy: 0.6923 - val_cls_output_loss: 0.8578 - val_loss: 1.0903 - val_seg_output_accuracy: 0.9268 - val_seg_output_loss: 0.2178
# Epoch 54/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.7138 - cls_output_loss: 0.6618 - loss: 0.8929 - seg_output_accuracy: 0.9227 - seg_output_loss: 0.2311
# Epoch 54: val_loss did not improve from 1.02660
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.7138 - cls_output_loss: 0.6628 - loss: 0.8939 - seg_output_accuracy: 0.9227 - seg_output_loss: 0.2311 - val_cls_output_accuracy: 0.6538 - val_cls_output_loss: 0.8364 - val_loss: 1.0625 - val_seg_output_accuracy: 0.9264 - val_seg_output_loss: 0.2168
# Epoch 55/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6570 - cls_output_loss: 0.7626 - loss: 0.9819 - seg_output_accuracy: 0.9276 - seg_output_loss: 0.2193
# Epoch 55: val_loss did not improve from 1.02660
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6581 - cls_output_loss: 0.7613 - loss: 0.9809 - seg_output_accuracy: 0.9274 - seg_output_loss: 0.2196 - val_cls_output_accuracy: 0.6346 - val_cls_output_loss: 0.8864 - val_loss: 1.1267 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2230
# Epoch 56/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.6868 - cls_output_loss: 0.7659 - loss: 0.9929 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2270
# Epoch 56: val_loss improved from 1.02660 to 1.02658, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.6873 - cls_output_loss: 0.7646 - loss: 0.9917 - seg_output_accuracy: 0.9250 - seg_output_loss: 0.2271 - val_cls_output_accuracy: 0.6603 - val_cls_output_loss: 0.8024 - val_loss: 1.0266 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2147
# Epoch 57/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - cls_output_accuracy: 0.6801 - cls_output_loss: 0.7049 - loss: 0.9334 - seg_output_accuracy: 0.9218 - seg_output_loss: 0.2285
# Epoch 57: val_loss did not improve from 1.02658
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.6804 - cls_output_loss: 0.7049 - loss: 0.9334 - seg_output_accuracy: 0.9218 - seg_output_loss: 0.2285 - val_cls_output_accuracy: 0.6603 - val_cls_output_loss: 0.8156 - val_loss: 1.0477 - val_seg_output_accuracy: 0.9264 - val_seg_output_loss: 0.2193
# Epoch 58/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7166 - cls_output_loss: 0.6433 - loss: 0.8688 - seg_output_accuracy: 0.9256 - seg_output_loss: 0.2256
# Epoch 58: val_loss improved from 1.02658 to 0.98846, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7166 - cls_output_loss: 0.6441 - loss: 0.8698 - seg_output_accuracy: 0.9255 - seg_output_loss: 0.2257 - val_cls_output_accuracy: 0.7115 - val_cls_output_loss: 0.7637 - val_loss: 0.9885 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2164
# Epoch 59/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7088 - cls_output_loss: 0.6981 - loss: 0.9247 - seg_output_accuracy: 0.9255 - seg_output_loss: 0.2266
# Epoch 59: val_loss did not improve from 0.98846
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7089 - cls_output_loss: 0.6978 - loss: 0.9245 - seg_output_accuracy: 0.9254 - seg_output_loss: 0.2267 - val_cls_output_accuracy: 0.6538 - val_cls_output_loss: 0.8030 - val_loss: 1.0243 - val_seg_output_accuracy: 0.9268 - val_seg_output_loss: 0.2144
# Epoch 60/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7507 - cls_output_loss: 0.6457 - loss: 0.8804 - seg_output_accuracy: 0.9203 - seg_output_loss: 0.2347
# Epoch 60: val_loss did not improve from 0.98846
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.7500 - cls_output_loss: 0.6465 - loss: 0.8811 - seg_output_accuracy: 0.9204 - seg_output_loss: 0.2346 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.8259 - val_loss: 1.0577 - val_seg_output_accuracy: 0.9257 - val_seg_output_loss: 0.2172
# Epoch 61/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7038 - cls_output_loss: 0.6843 - loss: 0.9056 - seg_output_accuracy: 0.9277 - seg_output_loss: 0.2213
# Epoch 61: val_loss did not improve from 0.98846
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7045 - cls_output_loss: 0.6836 - loss: 0.9051 - seg_output_accuracy: 0.9276 - seg_output_loss: 0.2215 - val_cls_output_accuracy: 0.6667 - val_cls_output_loss: 0.8057 - val_loss: 1.0353 - val_seg_output_accuracy: 0.9259 - val_seg_output_loss: 0.2204
# Epoch 62/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.7153 - cls_output_loss: 0.6633 - loss: 0.8967 - seg_output_accuracy: 0.9205 - seg_output_loss: 0.2334
# Epoch 62: val_loss improved from 0.98846 to 0.98573, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7156 - cls_output_loss: 0.6630 - loss: 0.8963 - seg_output_accuracy: 0.9206 - seg_output_loss: 0.2333 - val_cls_output_accuracy: 0.6987 - val_cls_output_loss: 0.7679 - val_loss: 0.9857 - val_seg_output_accuracy: 0.9275 - val_seg_output_loss: 0.2140
# Epoch 63/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.6606 - cls_output_loss: 0.7108 - loss: 0.9354 - seg_output_accuracy: 0.9256 - seg_output_loss: 0.2247
# Epoch 63: val_loss improved from 0.98573 to 0.97833, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.6616 - cls_output_loss: 0.7097 - loss: 0.9345 - seg_output_accuracy: 0.9255 - seg_output_loss: 0.2248 - val_cls_output_accuracy: 0.7244 - val_cls_output_loss: 0.7558 - val_loss: 0.9783 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2156
# Epoch 64/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7105 - cls_output_loss: 0.6606 - loss: 0.8957 - seg_output_accuracy: 0.9204 - seg_output_loss: 0.2351
# Epoch 64: val_loss did not improve from 0.97833
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7110 - cls_output_loss: 0.6604 - loss: 0.8953 - seg_output_accuracy: 0.9205 - seg_output_loss: 0.2349 - val_cls_output_accuracy: 0.6346 - val_cls_output_loss: 0.8749 - val_loss: 1.1017 - val_seg_output_accuracy: 0.9267 - val_seg_output_loss: 0.2194
# Epoch 65/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7197 - cls_output_loss: 0.6740 - loss: 0.8934 - seg_output_accuracy: 0.9269 - seg_output_loss: 0.2194
# Epoch 65: val_loss did not improve from 0.97833
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7197 - cls_output_loss: 0.6737 - loss: 0.8932 - seg_output_accuracy: 0.9269 - seg_output_loss: 0.2195 - val_cls_output_accuracy: 0.6987 - val_cls_output_loss: 0.7619 - val_loss: 0.9798 - val_seg_output_accuracy: 0.9274 - val_seg_output_loss: 0.2127
# Epoch 66/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7567 - cls_output_loss: 0.6111 - loss: 0.8551 - seg_output_accuracy: 0.9147 - seg_output_loss: 0.2440
# Epoch 66: val_loss did not improve from 0.97833
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.7562 - cls_output_loss: 0.6121 - loss: 0.8557 - seg_output_accuracy: 0.9150 - seg_output_loss: 0.2436 - val_cls_output_accuracy: 0.6218 - val_cls_output_loss: 0.8267 - val_loss: 1.0441 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2132
# Epoch 67/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7593 - cls_output_loss: 0.6056 - loss: 0.8153 - seg_output_accuracy: 0.9314 - seg_output_loss: 0.2098
# Epoch 67: val_loss did not improve from 0.97833
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7589 - cls_output_loss: 0.6066 - loss: 0.8168 - seg_output_accuracy: 0.9312 - seg_output_loss: 0.2102 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.7928 - val_loss: 1.0314 - val_seg_output_accuracy: 0.9271 - val_seg_output_loss: 0.2285
# Epoch 68/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - cls_output_accuracy: 0.7407 - cls_output_loss: 0.6691 - loss: 0.9040 - seg_output_accuracy: 0.9223 - seg_output_loss: 0.2349
# Epoch 68: val_loss improved from 0.97833 to 0.97042, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7410 - cls_output_loss: 0.6682 - loss: 0.9029 - seg_output_accuracy: 0.9223 - seg_output_loss: 0.2347 - val_cls_output_accuracy: 0.6987 - val_cls_output_loss: 0.7503 - val_loss: 0.9704 - val_seg_output_accuracy: 0.9269 - val_seg_output_loss: 0.2109
# Epoch 69/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7561 - cls_output_loss: 0.5980 - loss: 0.8313 - seg_output_accuracy: 0.9199 - seg_output_loss: 0.2333
# Epoch 69: val_loss improved from 0.97042 to 0.94094, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.7557 - cls_output_loss: 0.5987 - loss: 0.8318 - seg_output_accuracy: 0.9200 - seg_output_loss: 0.2331 - val_cls_output_accuracy: 0.7115 - val_cls_output_loss: 0.7252 - val_loss: 0.9409 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2121
# Epoch 70/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7435 - cls_output_loss: 0.6283 - loss: 0.8386 - seg_output_accuracy: 0.9305 - seg_output_loss: 0.2103
# Epoch 70: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.7434 - cls_output_loss: 0.6281 - loss: 0.8388 - seg_output_accuracy: 0.9304 - seg_output_loss: 0.2107 - val_cls_output_accuracy: 0.6090 - val_cls_output_loss: 0.8524 - val_loss: 1.0642 - val_seg_output_accuracy: 0.9270 - val_seg_output_loss: 0.2135
# Epoch 71/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7539 - cls_output_loss: 0.6314 - loss: 0.8517 - seg_output_accuracy: 0.9249 - seg_output_loss: 0.2202
# Epoch 71: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7533 - cls_output_loss: 0.6321 - loss: 0.8524 - seg_output_accuracy: 0.9249 - seg_output_loss: 0.2203 - val_cls_output_accuracy: 0.6795 - val_cls_output_loss: 0.7336 - val_loss: 0.9606 - val_seg_output_accuracy: 0.9273 - val_seg_output_loss: 0.2181
# Epoch 72/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7513 - cls_output_loss: 0.6388 - loss: 0.8662 - seg_output_accuracy: 0.9248 - seg_output_loss: 0.2274
# Epoch 72: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7512 - cls_output_loss: 0.6387 - loss: 0.8661 - seg_output_accuracy: 0.9248 - seg_output_loss: 0.2274 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.8453 - val_loss: 1.0823 - val_seg_output_accuracy: 0.9269 - val_seg_output_loss: 0.2223
# Epoch 73/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7303 - cls_output_loss: 0.6172 - loss: 0.8315 - seg_output_accuracy: 0.9297 - seg_output_loss: 0.2143
# Epoch 73: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.7303 - cls_output_loss: 0.6177 - loss: 0.8323 - seg_output_accuracy: 0.9295 - seg_output_loss: 0.2147 - val_cls_output_accuracy: 0.5962 - val_cls_output_loss: 0.8663 - val_loss: 1.0995 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2215
# Epoch 74/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7182 - cls_output_loss: 0.6753 - loss: 0.8965 - seg_output_accuracy: 0.9260 - seg_output_loss: 0.2212
# Epoch 74: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.7189 - cls_output_loss: 0.6738 - loss: 0.8951 - seg_output_accuracy: 0.9259 - seg_output_loss: 0.2213 - val_cls_output_accuracy: 0.6667 - val_cls_output_loss: 0.8009 - val_loss: 1.0187 - val_seg_output_accuracy: 0.9270 - val_seg_output_loss: 0.2116
# Epoch 75/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7597 - cls_output_loss: 0.6272 - loss: 0.8479 - seg_output_accuracy: 0.9266 - seg_output_loss: 0.2206
# Epoch 75: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7599 - cls_output_loss: 0.6266 - loss: 0.8473 - seg_output_accuracy: 0.9265 - seg_output_loss: 0.2208 - val_cls_output_accuracy: 0.6923 - val_cls_output_loss: 0.7439 - val_loss: 0.9627 - val_seg_output_accuracy: 0.9275 - val_seg_output_loss: 0.2135
# Epoch 76/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7510 - cls_output_loss: 0.6124 - loss: 0.8475 - seg_output_accuracy: 0.9192 - seg_output_loss: 0.2352
# Epoch 76: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7510 - cls_output_loss: 0.6122 - loss: 0.8473 - seg_output_accuracy: 0.9193 - seg_output_loss: 0.2351 - val_cls_output_accuracy: 0.6410 - val_cls_output_loss: 0.8836 - val_loss: 1.1221 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2203
# Epoch 77/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7238 - cls_output_loss: 0.6510 - loss: 0.8842 - seg_output_accuracy: 0.9214 - seg_output_loss: 0.2331
# Epoch 77: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7248 - cls_output_loss: 0.6495 - loss: 0.8825 - seg_output_accuracy: 0.9214 - seg_output_loss: 0.2330 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.7625 - val_loss: 0.9780 - val_seg_output_accuracy: 0.9278 - val_seg_output_loss: 0.2107
# Epoch 78/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7595 - cls_output_loss: 0.6005 - loss: 0.8237 - seg_output_accuracy: 0.9245 - seg_output_loss: 0.2231
# Epoch 78: val_loss did not improve from 0.94094
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7589 - cls_output_loss: 0.6014 - loss: 0.8247 - seg_output_accuracy: 0.9245 - seg_output_loss: 0.2233 - val_cls_output_accuracy: 0.6795 - val_cls_output_loss: 0.7327 - val_loss: 0.9571 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2150
# Epoch 79/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7773 - cls_output_loss: 0.5546 - loss: 0.7741 - seg_output_accuracy: 0.9269 - seg_output_loss: 0.2195
# Epoch 79: val_loss improved from 0.94094 to 0.92056, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.7772 - cls_output_loss: 0.5553 - loss: 0.7749 - seg_output_accuracy: 0.9269 - seg_output_loss: 0.2196 - val_cls_output_accuracy: 0.7179 - val_cls_output_loss: 0.7012 - val_loss: 0.9206 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2112
# Epoch 80/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7381 - cls_output_loss: 0.5965 - loss: 0.8249 - seg_output_accuracy: 0.9215 - seg_output_loss: 0.2283
# Epoch 80: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7383 - cls_output_loss: 0.5967 - loss: 0.8250 - seg_output_accuracy: 0.9216 - seg_output_loss: 0.2283 - val_cls_output_accuracy: 0.6667 - val_cls_output_loss: 0.8032 - val_loss: 1.0315 - val_seg_output_accuracy: 0.9262 - val_seg_output_loss: 0.2122
# Epoch 81/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7409 - cls_output_loss: 0.6004 - loss: 0.8322 - seg_output_accuracy: 0.9195 - seg_output_loss: 0.2318
# Epoch 81: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.7408 - cls_output_loss: 0.6003 - loss: 0.8320 - seg_output_accuracy: 0.9196 - seg_output_loss: 0.2317 - val_cls_output_accuracy: 0.6923 - val_cls_output_loss: 0.7589 - val_loss: 0.9823 - val_seg_output_accuracy: 0.9277 - val_seg_output_loss: 0.2134
# Epoch 82/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7424 - cls_output_loss: 0.6148 - loss: 0.8497 - seg_output_accuracy: 0.9201 - seg_output_loss: 0.2349
# Epoch 82: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7429 - cls_output_loss: 0.6141 - loss: 0.8488 - seg_output_accuracy: 0.9202 - seg_output_loss: 0.2347 - val_cls_output_accuracy: 0.6667 - val_cls_output_loss: 0.7706 - val_loss: 0.9888 - val_seg_output_accuracy: 0.9275 - val_seg_output_loss: 0.2113
# Epoch 83/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7699 - cls_output_loss: 0.5575 - loss: 0.7797 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2221
# Epoch 83: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7694 - cls_output_loss: 0.5578 - loss: 0.7800 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2222 - val_cls_output_accuracy: 0.6987 - val_cls_output_loss: 0.7163 - val_loss: 0.9343 - val_seg_output_accuracy: 0.9265 - val_seg_output_loss: 0.2119
# Epoch 84/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.7684 - cls_output_loss: 0.5784 - loss: 0.7980 - seg_output_accuracy: 0.9263 - seg_output_loss: 0.2196
# Epoch 84: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.7683 - cls_output_loss: 0.5785 - loss: 0.7984 - seg_output_accuracy: 0.9262 - seg_output_loss: 0.2199 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.7511 - val_loss: 0.9704 - val_seg_output_accuracy: 0.9271 - val_seg_output_loss: 0.2137
# Epoch 85/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7717 - cls_output_loss: 0.5556 - loss: 0.7931 - seg_output_accuracy: 0.9198 - seg_output_loss: 0.2375
# Epoch 85: val_loss did not improve from 0.92056
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.7714 - cls_output_loss: 0.5560 - loss: 0.7933 - seg_output_accuracy: 0.9199 - seg_output_loss: 0.2374 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.7086 - val_loss: 0.9265 - val_seg_output_accuracy: 0.9274 - val_seg_output_loss: 0.2110
# Epoch 86/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.7815 - cls_output_loss: 0.5616 - loss: 0.7865 - seg_output_accuracy: 0.9239 - seg_output_loss: 0.2249
# Epoch 86: val_loss improved from 0.92056 to 0.90857, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.7812 - cls_output_loss: 0.5614 - loss: 0.7863 - seg_output_accuracy: 0.9239 - seg_output_loss: 0.2249 - val_cls_output_accuracy: 0.7244 - val_cls_output_loss: 0.6888 - val_loss: 0.9086 - val_seg_output_accuracy: 0.9278 - val_seg_output_loss: 0.2140
# Epoch 87/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7649 - cls_output_loss: 0.5331 - loss: 0.7575 - seg_output_accuracy: 0.9235 - seg_output_loss: 0.2244
# Epoch 87: val_loss did not improve from 0.90857
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7647 - cls_output_loss: 0.5340 - loss: 0.7583 - seg_output_accuracy: 0.9235 - seg_output_loss: 0.2244 - val_cls_output_accuracy: 0.7051 - val_cls_output_loss: 0.6950 - val_loss: 0.9136 - val_seg_output_accuracy: 0.9277 - val_seg_output_loss: 0.2114
# Epoch 88/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7717 - cls_output_loss: 0.5386 - loss: 0.7676 - seg_output_accuracy: 0.9218 - seg_output_loss: 0.2290
# Epoch 88: val_loss did not improve from 0.90857
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - cls_output_accuracy: 0.7718 - cls_output_loss: 0.5388 - loss: 0.7678 - seg_output_accuracy: 0.9218 - seg_output_loss: 0.2289 - val_cls_output_accuracy: 0.7115 - val_cls_output_loss: 0.7382 - val_loss: 0.9687 - val_seg_output_accuracy: 0.9274 - val_seg_output_loss: 0.2165
# Epoch 89/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7680 - cls_output_loss: 0.5676 - loss: 0.7959 - seg_output_accuracy: 0.9210 - seg_output_loss: 0.2283
# Epoch 89: val_loss did not improve from 0.90857
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7680 - cls_output_loss: 0.5677 - loss: 0.7958 - seg_output_accuracy: 0.9211 - seg_output_loss: 0.2282 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.6982 - val_loss: 0.9251 - val_seg_output_accuracy: 0.9266 - val_seg_output_loss: 0.2187
# Epoch 90/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7437 - cls_output_loss: 0.5788 - loss: 0.8037 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2249
# Epoch 90: val_loss improved from 0.90857 to 0.88185, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.7439 - cls_output_loss: 0.5782 - loss: 0.8031 - seg_output_accuracy: 0.9251 - seg_output_loss: 0.2249 - val_cls_output_accuracy: 0.7244 - val_cls_output_loss: 0.6643 - val_loss: 0.8819 - val_seg_output_accuracy: 0.9277 - val_seg_output_loss: 0.2089
# Epoch 91/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7372 - cls_output_loss: 0.5767 - loss: 0.8083 - seg_output_accuracy: 0.9199 - seg_output_loss: 0.2317
# Epoch 91: val_loss did not improve from 0.88185
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7376 - cls_output_loss: 0.5762 - loss: 0.8077 - seg_output_accuracy: 0.9200 - seg_output_loss: 0.2315 - val_cls_output_accuracy: 0.7308 - val_cls_output_loss: 0.6848 - val_loss: 0.9057 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2127
# Epoch 92/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7717 - cls_output_loss: 0.5228 - loss: 0.7407 - seg_output_accuracy: 0.9279 - seg_output_loss: 0.2178
# Epoch 92: val_loss did not improve from 0.88185
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - cls_output_accuracy: 0.7714 - cls_output_loss: 0.5235 - loss: 0.7414 - seg_output_accuracy: 0.9278 - seg_output_loss: 0.2179 - val_cls_output_accuracy: 0.6731 - val_cls_output_loss: 0.7479 - val_loss: 0.9750 - val_seg_output_accuracy: 0.9266 - val_seg_output_loss: 0.2142
# Epoch 93/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7979 - cls_output_loss: 0.5460 - loss: 0.7700 - seg_output_accuracy: 0.9241 - seg_output_loss: 0.2240
# Epoch 93: val_loss did not improve from 0.88185
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7972 - cls_output_loss: 0.5468 - loss: 0.7709 - seg_output_accuracy: 0.9241 - seg_output_loss: 0.2241 - val_cls_output_accuracy: 0.7051 - val_cls_output_loss: 0.7057 - val_loss: 0.9317 - val_seg_output_accuracy: 0.9271 - val_seg_output_loss: 0.2160
# Epoch 94/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7912 - cls_output_loss: 0.5063 - loss: 0.7254 - seg_output_accuracy: 0.9263 - seg_output_loss: 0.2191
# Epoch 94: val_loss did not improve from 0.88185
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - cls_output_accuracy: 0.7911 - cls_output_loss: 0.5069 - loss: 0.7261 - seg_output_accuracy: 0.9262 - seg_output_loss: 0.2193 - val_cls_output_accuracy: 0.7051 - val_cls_output_loss: 0.7307 - val_loss: 0.9573 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2162
# Epoch 95/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7866 - cls_output_loss: 0.5226 - loss: 0.7315 - seg_output_accuracy: 0.9299 - seg_output_loss: 0.2089
# Epoch 95: val_loss improved from 0.88185 to 0.85099, saving model to best_model.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - cls_output_accuracy: 0.7866 - cls_output_loss: 0.5228 - loss: 0.7320 - seg_output_accuracy: 0.9298 - seg_output_loss: 0.2093 - val_cls_output_accuracy: 0.7372 - val_cls_output_loss: 0.6361 - val_loss: 0.8510 - val_seg_output_accuracy: 0.9277 - val_seg_output_loss: 0.2100
# Epoch 96/100
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7704 - cls_output_loss: 0.5363 - loss: 0.7759 - seg_output_accuracy: 0.9180 - seg_output_loss: 0.2396
# Epoch 96: val_loss did not improve from 0.85099
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7705 - cls_output_loss: 0.5362 - loss: 0.7756 - seg_output_accuracy: 0.9181 - seg_output_loss: 0.2394 - val_cls_output_accuracy: 0.7179 - val_cls_output_loss: 0.6728 - val_loss: 0.8945 - val_seg_output_accuracy: 0.9272 - val_seg_output_loss: 0.2138
# Epoch 97/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - cls_output_accuracy: 0.7851 - cls_output_loss: 0.4936 - loss: 0.7201 - seg_output_accuracy: 0.9240 - seg_output_loss: 0.2266
# Epoch 97: val_loss did not improve from 0.85099
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - cls_output_accuracy: 0.7849 - cls_output_loss: 0.4943 - loss: 0.7208 - seg_output_accuracy: 0.9240 - seg_output_loss: 0.2265 - val_cls_output_accuracy: 0.7115 - val_cls_output_loss: 0.6717 - val_loss: 0.8906 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2083
# Epoch 98/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - cls_output_accuracy: 0.7830 - cls_output_loss: 0.5088 - loss: 0.7449 - seg_output_accuracy: 0.9183 - seg_output_loss: 0.2361
# Epoch 98: val_loss did not improve from 0.85099
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - cls_output_accuracy: 0.7829 - cls_output_loss: 0.5089 - loss: 0.7447 - seg_output_accuracy: 0.9184 - seg_output_loss: 0.2358 - val_cls_output_accuracy: 0.7115 - val_cls_output_loss: 0.6728 - val_loss: 0.8966 - val_seg_output_accuracy: 0.9276 - val_seg_output_loss: 0.2128
# Epoch 99/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7918 - cls_output_loss: 0.4948 - loss: 0.7297 - seg_output_accuracy: 0.9190 - seg_output_loss: 0.2348
# Epoch 99: val_loss did not improve from 0.85099
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - cls_output_accuracy: 0.7915 - cls_output_loss: 0.4953 - loss: 0.7299 - seg_output_accuracy: 0.9192 - seg_output_loss: 0.2345 - val_cls_output_accuracy: 0.6987 - val_cls_output_loss: 0.7935 - val_loss: 1.0260 - val_seg_output_accuracy: 0.9273 - val_seg_output_loss: 0.2156
# Epoch 100/100
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - cls_output_accuracy: 0.7925 - cls_output_loss: 0.4715 - loss: 0.7074 - seg_output_accuracy: 0.9178 - seg_output_loss: 0.2359
# Epoch 100: val_loss did not improve from 0.85099
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - cls_output_accuracy: 0.7919 - cls_output_loss: 0.4727 - loss: 0.7083 - seg_output_accuracy: 0.9180 - seg_output_loss: 0.2356 - val_cls_output_accuracy: 0.6859 - val_cls_output_loss: 0.6953 - val_loss: 0.9149 - val_seg_output_accuracy: 0.9280 - val_seg_output_loss: 0.2081

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#e5a3a3 ;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Model Evaluation 📈</p>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import numpy as np

# ---------- SEGMENTATION METRICS ---------- #
def mean_iou(y_true, y_pred):
    y_pred = (y_pred > 0.5).astype(np.uint8)
    y_true = y_true.astype(np.uint8)
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    return intersection / union if union != 0 else 1.0

def dice_coefficient(y_true, y_pred):
    y_pred = (y_pred > 0.5).astype(np.uint8)
    y_true = y_true.astype(np.uint8)
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection) / (np.sum(y_true) + np.sum(y_pred) + 1e-7)

def pixel_accuracy(y_true, y_pred):
    y_pred = (y_pred > 0.5).astype(np.uint8)
    y_true = y_true.astype(np.uint8)
    correct = (y_true == y_pred).sum()
    total = np.prod(y_true.shape)
    return correct / total

# %%
# Predict outputs
Y_pred_seg, Y_pred_cls = model.predict(X_test)

# Round segmentation output
Y_pred_seg_binary = (Y_pred_seg > 0.5).astype(np.uint8)

# Convert one-hot encoded labels to class indices
Y_class_test_labels = np.argmax(Y_class_test, axis=1)
Y_pred_cls_labels = np.argmax(Y_pred_cls, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 791ms/step

# %%
iou_scores = [mean_iou(y_true, y_pred) for y_true, y_pred in zip(Y_test, Y_pred_seg_binary)]
dice_scores = [dice_coefficient(y_true, y_pred) for y_true, y_pred in zip(Y_test, Y_pred_seg_binary)]
pixel_accuracies = [pixel_accuracy(y_true, y_pred) for y_true, y_pred in zip(Y_test, Y_pred_seg_binary)]

print("Segmentation Metrics:")
print(f"Mean IoU        : {np.mean(iou_scores):.4f}")
print(f"Dice Coefficient: {np.mean(dice_scores):.4f}")
print(f"Pixel Accuracy  : {np.mean(pixel_accuracies):.4f}")
# Out:
# Segmentation Metrics:
# Mean IoU        : 0.1918
# Dice Coefficient: 0.2277
# Pixel Accuracy  : 0.9299

# %%
print("\nClassification Metrics:")
print(f"Accuracy : {accuracy_score(Y_class_test_labels, Y_pred_cls_labels):.4f}")
print(f"Precision: {precision_score(Y_class_test_labels, Y_pred_cls_labels, average='weighted'):.4f}")
print(f"Recall   : {recall_score(Y_class_test_labels, Y_pred_cls_labels, average='weighted'):.4f}")
print(f"F1-Score : {f1_score(Y_class_test_labels, Y_pred_cls_labels, average='weighted'):.4f}")

# Optional: Detailed report
print("\nClassification Report:")
print(classification_report(Y_class_test_labels, Y_pred_cls_labels, target_names=['Benign', 'Malignant', 'Normal'])) #Added Normal
# Out:
# Classification Metrics:
# Accuracy : 0.6859
# Precision: 0.7165
# Recall   : 0.6859
# F1-Score : 0.6715
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.72      0.80      0.76        84
#    Malignant       0.58      0.72      0.65        43
#       Normal       0.90      0.31      0.46        29
#
#     accuracy                           0.69       156
#    macro avg       0.74      0.61      0.62       156
# weighted avg       0.72      0.69      0.67       156

# %%
# Save the trained model
model.save("Latest_breast_ultrasound_multitask_model.h5")
print("Model saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.

# %%
# Build the model
model = build_multi_output_unet()

# Print the model architecture
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │        160 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 128, 128,  │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 64, 64,    │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 128,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ conv2d_8[0][0]    │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_7[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 256, 256,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ seg_output (Conv2D) │ (None, 256, 256,  │         17 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cls_output (Dense)  │ (None, 3)         │        195 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 62,276 (243.27 KB)
#  Trainable params: 62,276 (243.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model

# Build the model instance
model = build_multi_output_unet()

# Plot and save the model architecture
plot_model(model, to_file='build_multi_output_unet.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Final Model Test with Random Image

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Load the saved model (Updated to the new model filename)
model = load_model("Latest_breast_ultrasound_multitask_model.h5")
print("Model loaded successfully.")

# ----------- STEP 1: Load and preprocess external image -----------
def preprocess_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256, 256))
    img = cv2.GaussianBlur(img, (3, 3), 0)
    img = img / 255.0
    img = img.reshape(1, 256, 256, 1)
    return img

# ----------- STEP 2: Predict segmentation and class -----------
def predict_external_image(image_path):
    img_input = preprocess_image(image_path)
    pred_mask, pred_class = model.predict(img_input)

    pred_mask = pred_mask[0, :, :, 0]  # remove batch dimension
    pred_class_label = np.argmax(pred_class[0])

    # Updated class names to include Normal
    class_names = ["Benign", "Malignant", "Normal"]
    class_name = class_names[pred_class_label]

    # ----------- STEP 3: Display results -----------
    plt.figure(figsize=(12, 4))

    # Original Image
    plt.subplot(1, 3, 1)
    plt.imshow(img_input[0, :, :, 0], cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    # Predicted Mask
    plt.subplot(1, 3, 2)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Segmentation")
    plt.axis("off")

    # Classification (Updated to display the correct class)
    plt.subplot(1, 3, 3)
    plt.text(0.5, 0.5, f"Prediction:\n{class_name}", fontsize=18,
             horizontalalignment='center', verticalalignment='center')
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# ----------- STEP 4: Call function with your image path -----------
image_path = "/content/malignant (1).png"  # <-- CHANGE THIS TO YOUR IMAGE
predict_external_image(image_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Load the saved model
model = load_model("breast_ultrasound_multitask_model.h5")
print("Model loaded successfully.")

# ----------- STEP 1: Load and preprocess external image -----------
def preprocess_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256, 256))
    img = cv2.GaussianBlur(img, (3, 3), 0)
    img = img / 255.0
    img = img.reshape(1, 256, 256, 1)
    return img

# ----------- STEP 2: Predict segmentation and class -----------
def predict_external_image(image_path):
    img_input = preprocess_image(image_path)
    pred_mask, pred_class = model.predict(img_input)

    pred_mask = pred_mask[0, :, :, 0]  # remove batch dimension
    pred_class_label = np.argmax(pred_class[0])

    class_name = "Benign" if pred_class_label == 0 else "Malignant"

    # ----------- STEP 3: Display results -----------
    plt.figure(figsize=(12, 4))

    # Original Image
    plt.subplot(1, 3, 1)
    plt.imshow(img_input[0, :, :, 0], cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    # Predicted Mask
    plt.subplot(1, 3, 2)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Segmentation")
    plt.axis("off")

    # Classification
    plt.subplot(1, 3, 3)
    plt.text(0.5, 0.5, f"Prediction:\n{class_name}", fontsize=18,
             horizontalalignment='center', verticalalignment='center')
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# ----------- STEP 4: Call function with your image path -----------
image_path = "/content/benign (1).png"  # <-- CHANGE THIS TO YOUR IMAGE
predict_external_image(image_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load both models
segmentation_model = load_model('Evaluate_U_net.h5')


multitask_model = load_model("breast_ultrasound_multitask_model.h5")
def preprocess_image(image_path, apply_blur=False):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256, 256))
    if apply_blur:
        img = cv2.GaussianBlur(img, (3, 3), 0)
    img = img / 255.0
    return img.reshape(1, 256, 256, 1)

def run_full_prediction(image_path):
    # -------- Segmentation and malignancy check from Evaluate_U_net.h5 --------
    seg_input = preprocess_image(image_path)
    seg_pred = segmentation_model.predict(seg_input)
    seg_mask = (seg_pred > 0.5).astype(np.uint8)
    malignant_percentage = np.sum(seg_mask) / (256 * 256) * 100

    flag = True if malignant_percentage < 5 else False
    status_from_seg = "Malignant" if not flag else "Benign"

    print(f"[U-Net] Prediction: {status_from_seg}")
    print(f"[U-Net] Malignant percentage: {malignant_percentage:.2f}%")

    # -------- Classification and segmentation from multitask model --------
    multi_input = preprocess_image(image_path, apply_blur=True)
    pred_mask, pred_class = multitask_model.predict(multi_input)

    pred_mask = pred_mask[0, :, :, 0]
    pred_class_label = np.argmax(pred_class[0])
    status_from_class = "Malignant" if pred_class_label == 1 else "Benign"

    print(f"[Multitask Model] Prediction: {status_from_class}")

    # -------- Display results --------
    plt.figure(figsize=(12, 4))

    # Original Image
    plt.subplot(1, 3, 1)
    plt.imshow(multi_input[0, :, :, 0], cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    # Predicted Mask
    plt.subplot(1, 3, 2)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Multitask Segmentation")
    plt.axis("off")

    # Classification Output
    plt.subplot(1, 3, 3)
    plt.text(0.5, 0.5, f"Prediction:\n{status_from_seg}", fontsize=18,
             horizontalalignment='center', verticalalignment='center')
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# -------- Run everything --------
image_path = "/content/malignant (1).png"  # <-- Change this to your image
run_full_prediction(image_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [U-Net] Prediction: Malignant
# [U-Net] Malignant percentage: 27.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# [Multitask Model] Prediction: Benign

# %% [markdown]
# ###
